# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Akshaya_Bonu-resume (2).pdf'
#  Akshaya_Bonu_Resume.pdf
# 'Akshaya-Resume (1).pdf'
# 'Akshaya_RESUME (1).pdf'
#  Akshaya-resume.pdf
#  Akshaya-Resume.pdf
#  Akshaya_RESUME.pdf
#  architecture_diagram.drawio.png
#  BonuAkshaya_LPU_EVSmartAssistant
#  chest_xray
# 'Colab Notebooks'
# 'Copy of Lecture8_py (1).pdf'
# 'Copy of Lecture8_py.pdf'
# 'cv ake.png'
#  D.pdf
# 'final petant (2).pdf'
#  gradesheet2.png
#  ID1-min.jpg
#  ID2-min.jpg
#  IDcardB.png
#  IDcard.png
#  IMG-20240902-WA0021.jpg
#  IMG-20240903-WA0026.jpg
#  InShot_20240430_201522926.mp4
# 'K23AMB50 Akshaya (1).pdf'
# 'K23AMB50 Akshaya.pdf'
# 'MATH CA#.xlsx'
# 'MATHS CA3-12322147.pdf'
#  mycv232.docx
#  mycv232.pdf
# 'nissi video cv.mp4'
# 'Patent AI.pdf'
#  Plant_Disease_Detection_Report.pdf
#  pneumonia-disease-detection.zip
#  pneumonia_final.keras
#  pneumonia_model.keras
#  pneumonia_xray_dataset
#  Screenshot_2023-08-28-21-07-10-71_944a2809ea1b4cda6ef12d1db9048ed3.jpg
#  Screenshot_2024-03-18-20-43-27-23_944a2809ea1b4cda6ef12d1db9048ed3.jpg
# 'Screenshot 2024-09-20 103937.png'
# 'Screenshot 2024-09-20 105553.png'
#  Screenshot_2025-10-01-10-19-24-65_6012fa4d4ddec268fc5c7112cbb265e7.jpg
# 'Student CV #12903.gslides'
# 'Untitled form.gform'
# 'video cv.mp4'

# %%
import tensorflow as tf

model = tf.keras.models.load_model("/content/drive/MyDrive/pneumonia_final.keras")

print("✅ Model loaded successfully!")
model.summary()
# Out:
# ✅ Model loaded successfully!
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,281 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,972,037 (22.78 MB)
#  Trainable params: 1,856,385 (7.08 MB)
#  Non-trainable params: 402,880 (1.54 MB)
#  Optimizer params: 3,712,772 (14.16 MB)

# %%
import numpy as np
import matplotlib.pyplot as plt

IMG_SIZE = 224

img_path = "/content/drive/MyDrive/chest_xray/test/NORMAL/IM-0009-0001.jpeg"
# OR use any image from PNEUMONIA folder

img = tf.keras.utils.load_img(img_path, target_size=(224,224))
img_array = tf.keras.utils.img_to_array(img)/255.0
img_array = img_array[None, ...]

prob = model.predict(img_array)[0][0]
label = "PNEUMONIA" if prob > 0.5 else "NORMAL"

plt.imshow(img)
plt.title(f"Prediction: {label}")
plt.axis("off")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
